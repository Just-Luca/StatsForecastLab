# %%
# from pmdarima import auto_arima
# from src.utils import process_data

# _, df, _ = process_data()

# model = auto_arima(df['y'], seasonal=True, m=1, stepwise=True, trace=True)
# print(model.summary())

# %%
from src.utils import process_data
df_1, df_2, df_3 = process_data()
df_1
# Out:
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\statsforecast\core.py:26: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#        unique_id                  ds        y
# 0           HUFL 2016-07-01 00:00:00  5.82700
# 1           HUFL 2016-07-01 01:00:00  5.69300
# 2           HUFL 2016-07-01 02:00:00  5.15700
# 3           HUFL 2016-07-01 03:00:00  5.09000
# 4           HUFL 2016-07-01 04:00:00  5.35800
# ...          ...                 ...      ...
# 243875      OT.1 2018-06-26 15:00:00  6.05272
# 243876      OT.1 2018-06-26 16:00:00  6.05272
# 243877      OT.1 2018-06-26 17:00:00  6.05272
# 243878      OT.1 2018-06-26 18:00:00  6.05272
# 243879      OT.1 2018-06-26 19:00:00  6.05272
#
# [243880 rows x 3 columns]

# %%
# from src.utils import get_id
# get_id()

# %%
# from src.utils import id_control
# id_control("ciao")

# %%
# from src.utils import get_n_windows
# get_n_windows(df_1, 24)

# %%
from src.hup_statsmacrocast import HupStatsMacrocast

# %%
hsm = HupStatsMacrocast(normalization=True)

# %%
hsm.predict()
# Out:
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Currently running: [24, 'log', 'HistoricAverage']
# Currently running: [24, 'log', 'Naive']
# Currently running: [24, 'log', 'ARIMA']
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Currently running: [24, 'log', 'AutoARIMA']
# Currently running: [24, 'identity', 'HistoricAverage']
# Currently running: [24, 'identity', 'Naive']
# Currently running: [24, 'identity', 'ARIMA']
# Currently running: [24, 'identity', 'AutoARIMA']

# %%
hsm.cross_validation()
# Out:
# Currently running: [24, 'log', 'HistoricAverage']
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Currently running: [24, 'log', 'Naive']
# Currently running: [24, 'log', 'ARIMA']
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Currently running: [24, 'log', 'AutoARIMA']
# Currently running: [24, 'identity', 'HistoricAverage']
# Currently running: [24, 'identity', 'Naive']
# Currently running: [24, 'identity', 'ARIMA']
# Currently running: [24, 'identity', 'AutoARIMA']

# %%
hsm.best_results_plots(result="forecast", actual=True)
# Out:
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)

# %%
hsm.best_results_metric_dataframe()
# Out:
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#    metric unique_id  metric_value best_model transformation
# 0     mae      HUFL      0.218849  AutoARIMA       identity
# 1     mae    HUFL.1      0.183629  AutoARIMA       identity
# 2     mae      HULL      0.169912  AutoARIMA       identity
# 3     mae    HULL.1      0.209991  AutoARIMA       identity
# 4     mae      LUFL      0.214346  AutoARIMA       identity
# 5     mae    LUFL.1      0.258864  AutoARIMA       identity
# 6     mae      LULL      0.252689  AutoARIMA       identity
# 7     mae    LULL.1      0.144376      Naive            log
# 8     mae      MUFL      0.198136  AutoARIMA       identity
# 9     mae    MUFL.1      0.245387      Naive            log
# 10    mae      MULL      0.197827  AutoARIMA       identity
# 11    mae    MULL.1      0.222725  AutoARIMA       identity
# 12    mae        OT      0.265666  AutoARIMA       identity
# 13    mae      OT.1      0.141593  AutoARIMA       identity
