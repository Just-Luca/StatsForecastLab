# %%
# from pmdarima import auto_arima
# from src.utils import process_data

# _, df, _ = process_data()

# model = auto_arima(df['y'], seasonal=True, m=1, stepwise=True, trace=True)
# print(model.summary())

# %%
from src.utils import process_data
df_1, df_2, df_3 = process_data()
df_1
# Out:
#        unique_id                  ds        y
# 0           HUFL 2016-07-01 00:00:00  5.82700
# 1           HUFL 2016-07-01 01:00:00  5.69300
# 2           HUFL 2016-07-01 02:00:00  5.15700
# 3           HUFL 2016-07-01 03:00:00  5.09000
# 4           HUFL 2016-07-01 04:00:00  5.35800
# ...          ...                 ...      ...
# 243875      OT.1 2018-06-26 15:00:00  6.05272
# 243876      OT.1 2018-06-26 16:00:00  6.05272
# 243877      OT.1 2018-06-26 17:00:00  6.05272
# 243878      OT.1 2018-06-26 18:00:00  6.05272
# 243879      OT.1 2018-06-26 19:00:00  6.05272
#
# [243880 rows x 3 columns]

# %%
df_1[df_1["unique_id"] == "HUFL"]
# Out:
#       unique_id                  ds       y
# 0          HUFL 2016-07-01 00:00:00   5.827
# 1          HUFL 2016-07-01 01:00:00   5.693
# 2          HUFL 2016-07-01 02:00:00   5.157
# 3          HUFL 2016-07-01 03:00:00   5.090
# 4          HUFL 2016-07-01 04:00:00   5.358
# ...         ...                 ...     ...
# 17415      HUFL 2018-06-26 15:00:00  -1.674
# 17416      HUFL 2018-06-26 16:00:00  -5.492
# 17417      HUFL 2018-06-26 17:00:00   2.813
# 17418      HUFL 2018-06-26 18:00:00   9.243
# 17419      HUFL 2018-06-26 19:00:00  10.114
#
# [17420 rows x 3 columns]

# %%
# from src.utils import get_id
# get_id()

# %%
# from src.utils import id_control
# id_control("ciao")

# %%
# from src.utils import get_n_windows
# get_n_windows(df_1, 24)

# %%
from src.hup_statsmacrocast import HupStatsMacrocast

# %%
hsm = HupStatsMacrocast(normalization=True)

# %%
hsm.predict()
# Out:
# Currently running: [72, 'identity', 'Naive']
# Currently running: [72, 'identity', 'ARIMA']
# Currently running: [72, 'identity', 'ARIMA_sl24']
# Currently running: [72, 'identity', 'AutoARIMA']
# Currently running: [72, 'identity', 'AutoARIMA_sl24']
# Currently running: [72, 'identity', 'AutoETS']
# Currently running: [72, 'identity', 'AutoETS_sl24']
# Currently running: [48, 'identity', 'Naive']
# Currently running: [48, 'identity', 'ARIMA']
# Currently running: [48, 'identity', 'ARIMA_sl24']
# Currently running: [48, 'identity', 'AutoARIMA']
# Currently running: [48, 'identity', 'AutoARIMA_sl24']
# Currently running: [48, 'identity', 'AutoETS']
# Currently running: [48, 'identity', 'AutoETS_sl24']
# Currently running: [24, 'identity', 'Naive']
# Currently running: [24, 'identity', 'ARIMA']
# Currently running: [24, 'identity', 'ARIMA_sl24']
# Currently running: [24, 'identity', 'AutoARIMA']
# Currently running: [24, 'identity', 'AutoARIMA_sl24']
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
hsm.cross_validation()
# Out:
# Currently running: [72, 'identity', 'ARIMA']
# Currently running: [48, 'identity', 'ARIMA']
# Currently running: [24, 'identity', 'ARIMA']

# %%
hsm.best_results_plots(result="forecast", actual=True)
# Out:
# c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\utils.py:269: RuntimeWarning: divide by zero encountered in divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\utils.py:269: RuntimeWarning: divide by zero encountered in divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\utils.py:269: RuntimeWarning: divide by zero encountered in divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\utils.py:269: RuntimeWarning: divide by zero encountered in divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\utils.py:269: RuntimeWarning: divide by zero encountered in divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\utils.py:269: RuntimeWarning: divide by zero encountered in divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
hsm.best_results_metric_dataframe()
# Out:
#    metric unique_id  metric_value best_model transformation
# 0     mae      HUFL      0.190893      ARIMA       identity
# 1     mae    HUFL.1      0.226091      ARIMA       identity
# 2     mae      HULL      0.235496      ARIMA       identity
# 3     mae    HULL.1      0.231700      ARIMA       identity
# 4     mae      LUFL      0.181365      ARIMA       identity
# 5     mae    LUFL.1      0.214510      ARIMA       identity
# 6     mae      LULL      0.246651      ARIMA       identity
# 7     mae    LULL.1      0.264004      ARIMA       identity
# 8     mae      MUFL      0.179209      ARIMA       identity
# 9     mae    MUFL.1      0.220349      ARIMA       identity
# 10    mae      MULL      0.153537      ARIMA       identity
# 11    mae    MULL.1      0.024453      ARIMA       identity
# 12    mae        OT      0.029446      ARIMA       identity
# 13    mae      OT.1      0.151557      ARIMA       identity
