# %%
# from pmdarima import auto_arima
# from src.utils import process_data

# _, df, _ = process_data()

# model = auto_arima(df['y'], seasonal=True, m=1, stepwise=True, trace=True)
# print(model.summary())

# %%
from src.utils import process_data
df_1, df_2, df_3 = process_data()

# %%
df_1
# Out:
#        unique_id                  ds        y
# 0           HUFL 2016-07-01 00:00:00  5.82700
# 1           HUFL 2016-07-01 01:00:00  5.69300
# 2           HUFL 2016-07-01 02:00:00  5.15700
# 3           HUFL 2016-07-01 03:00:00  5.09000
# 4           HUFL 2016-07-01 04:00:00  5.35800
# ...          ...                 ...      ...
# 243875      OT.1 2018-06-26 15:00:00  6.05272
# 243876      OT.1 2018-06-26 16:00:00  6.05272
# 243877      OT.1 2018-06-26 17:00:00  6.05272
# 243878      OT.1 2018-06-26 18:00:00  6.05272
# 243879      OT.1 2018-06-26 19:00:00  6.05272
#
# [243880 rows x 3 columns]

# %%
df_2
# Out:
#        unique_id                  ds         y
# 0           HUFL 2016-07-01 00:00:00  5.827000
# 1           HUFL 2016-07-01 01:00:00  5.693000
# 2           HUFL 2016-07-01 02:00:00  5.157000
# 3           HUFL 2016-07-01 03:00:00  5.090000
# 4           HUFL 2016-07-01 04:00:00  5.358000
# ...          ...                 ...       ...
# 233445      OT.1 2018-05-26 14:00:00  4.615655
# 233446      OT.1 2018-05-26 15:00:00  4.615655
# 233447      OT.1 2018-05-26 16:00:00  4.615655
# 233448      OT.1 2018-05-26 17:00:00  4.615655
# 233449      OT.1 2018-05-26 18:00:00  4.615655
#
# [233450 rows x 3 columns]

# %%
df_3
# Out:
#       unique_id                  ds         y
# 0          HUFL 2018-05-26 19:00:00   9.91300
# 1          HUFL 2018-05-26 20:00:00  10.24800
# 2          HUFL 2018-05-26 21:00:00   8.97500
# 3          HUFL 2018-05-26 22:00:00   9.98000
# 4          HUFL 2018-05-26 23:00:00  12.79300
# ...         ...                 ...       ...
# 10425      OT.1 2018-06-26 15:00:00   6.05272
# 10426      OT.1 2018-06-26 16:00:00   6.05272
# 10427      OT.1 2018-06-26 17:00:00   6.05272
# 10428      OT.1 2018-06-26 18:00:00   6.05272
# 10429      OT.1 2018-06-26 19:00:00   6.05272
#
# [10430 rows x 3 columns]

# %%
from src.hup_statsmacrocast import HupStatsMacrocast
# Out:
# c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\statsforecast\core.py:26: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
hsm = HupStatsMacrocast(normalization=True)

# %%
hsm.predict()
# Out:
# Currently running: [7, 'identity', 'AutoARIMA']

# %%
hsm.cross_validation()
# Out:
# Currently running: [7, 'identity', 'AutoARIMA']

# %%
hsm.best_results_plots(result="forecast", actual=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 hsm.best_results_plots(result="forecast", actual=True)
#
# File c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\hup_statsmacrocast.py:166, in HupStatsMacrocast.best_results_plots(self, horizon, metric, result, eval_horizon, countries, actual)
#     163 else:
#     164     pass
# --> 166 df_crossval = self.best_results_prediction_dataframe(
#     167     horizon=horizon,
#     168     result='crossval',
#     169     metric=metric,
#     170     countries=countries
#     171 )
#     173 match result:
#     174     case 'forecast':
#
# File c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\hup_statsmacrocast.py:379, in HupStatsMacrocast.best_results_prediction_dataframe(self, horizon, metric, result, countries)
#     375     pass
#     377 ids = utils.id_control(countries)
# --> 379 metric_best_results_df = self.best_results_metric_dataframe(
#     380     horizon=horizon,
#     381     metric=metric,
#     382     result=result
#     383 )
#     385 best_results = metric_best_results_df.set_index('unique_id').drop(columns=['metric', 'metric_value']).to_dict('index')
#     387 if result == 'forecast':
#
# File c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\hup_statsmacrocast.py:268, in HupStatsMacrocast.best_results_metric_dataframe(self, horizon, metric, result)
#     261 def best_results_metric_dataframe(
#     262         self,
#     263         horizon: int = gsp.HORIZONS[0],
#     264         metric: str = "mae",
#     265         result: str = "forecast"
#     266     ):
# --> 268     self.best_model_metric_evaluation(result=result)
#     270     metric_results_df = pd.DataFrame()
#     272     for transformation in self.transformations:
#
# File c:\Users\giust\projects\volatility-forecasting-master\Nixtla\StatsForecast\src\hup_statsmacrocast.py:234, in HupStatsMacrocast.best_model_metric_evaluation(self, result)
#     232 elif result == "crossval":
#     233     metric_results_path = cross_metric_results_path
# --> 234     df_crossval = pd.read_csv(cv_results_path)
#     235     if Path.exists(metric_results_path):
#     236             continue
#
# File c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\giust\projects\volatility-forecasting-master\fore_venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\giust\\projects\\volatility-forecasting-master\\Nixtla\\StatsForecast\\results_norm\\horizon=7\\SF_container_identity\\stats_training\\stats_training_results_(nw=2364)\\cv_df_(nw=2364).csv'

# %%
hsm.best_results_metric_dataframe()
# Out:
#    metric unique_id  metric_value                   best_model transformation
# 0     mae      HUFL      0.035592                      AutoETS       identity
# 1     mae    HUFL.1      0.241681              HistoricAverage       identity
# 2     mae      HULL      0.107978                SeasNaive_sl7       identity
# 3     mae    HULL.1      0.154973                   GARCH(1,1)       identity
# 4     mae      LUFL      0.240922              HistoricAverage       identity
# 5     mae    LUFL.1      0.095795  SeasNaive_sl1_HoltWinters_x       identity
# 6     mae      LULL      0.026363                      AutoETS       identity
# 7     mae    LULL.1      0.120074                        ARIMA       identity
# 8     mae      MUFL      0.165930                   GARCH(2,1)       identity
# 9     mae    MUFL.1      0.128820  SeasNaive_sl1_HoltWinters_x       identity
# 10    mae      MULL      0.296353                SeasNaive_sl7       identity
# 11    mae    MULL.1      0.298819                SeasNaive_sl7       identity
# 12    mae        OT      0.109074              HistoricAverage       identity
# 13    mae      OT.1      0.221284              HistoricAverage       identity
